# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct


import pandas as pd
import openai

# %%
qdrant_client = QdrantClient(
    url="http://localhost:6333",
)

# %%
qdrant_client.create_collection(
    collection_name="Amazon-items-collection-02",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)

# %%
import pandas as pd

df_items = pd.read_json("../data/meta_Electronics_1000.jsonl", lines=True)

df_items.head(3)
# Out:
#      main_category                                              title  \
# 0  All Electronics  Adjustable Metal Stand for E cho Show 15, Tilt...
# 1        Computers  HP Laptop, 15.6" HD Touchscreen, AMD Athlon Go...
# 2      Amazon Home  50 Pcs Groot Stickers for Water Bottle Waterpr...
#
#    average_rating  rating_number  \
# 0             4.5            111
# 1             4.4            205
# 2             4.7            156
#
#                                             features  \
# 0  [The VMEI adjustable metal bracket is made of ...
# 1  [【High Speed RAM And Enormous Space】8GB high-b...
# 2  [🏆Groot Stickers:Anime theme party favors for ...
#
#                                          description  price  \
# 0                                                 []  36.99
# 1  [PConline365 sells computers with professional...    NaN
# 2  [Groot Stickers Quantity: 50 Pcs/pack.Non-dupl...   5.99
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos    store  \
# 0  [{'title': 'Small footprint, minimalist design...     VMEI
# 1                                                 []       HP
# 2  [{'title': '200-Piece Stickers Pack for Laptop...  Fcelery
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
# 2  [Electronics, Computers & Accessories, Laptop ...
#
#                                              details parent_asin  \
# 0  {'Brand': 'VMEI', 'Color': 'Black', 'Room Type...  B0B13T2GY5
# 1  {'Brand': 'HP', 'Color': 'Silver', 'Room Type'...  B08DC5KLJZ
# 2  {'Brand': 'Fcelery', 'Color': 'Groot', 'Room T...  B0B4QQSRY3
#
#    bought_together available_date
# 0              NaN     2022-05-11
# 1              NaN     2022-03-24
# 2              NaN     2022-06-22

# %%
def preprocess_data(row):
    return f"{row['title']} {' '.join(row['features'])}"

# %%
df_items["preprocessed_data"] = df_items.apply(preprocess_data, axis=1)

df_items.head(2)
# Out:
#      main_category                                              title  \
# 0  All Electronics  Adjustable Metal Stand for E cho Show 15, Tilt...
# 1        Computers  HP Laptop, 15.6" HD Touchscreen, AMD Athlon Go...
#
#    average_rating  rating_number  \
# 0             4.5            111
# 1             4.4            205
#
#                                             features  \
# 0  [The VMEI adjustable metal bracket is made of ...
# 1  [【High Speed RAM And Enormous Space】8GB high-b...
#
#                                          description  price  \
# 0                                                 []  36.99
# 1  [PConline365 sells computers with professional...    NaN
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos store  \
# 0  [{'title': 'Small footprint, minimalist design...  VMEI
# 1                                                 []    HP
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
#
#                                              details parent_asin  \
# 0  {'Brand': 'VMEI', 'Color': 'Black', 'Room Type...  B0B13T2GY5
# 1  {'Brand': 'HP', 'Color': 'Silver', 'Room Type'...  B08DC5KLJZ
#
#    bought_together available_date  \
# 0              NaN     2022-05-11
# 1              NaN     2022-03-24
#
#                                    preprocessed_data
# 0  Adjustable Metal Stand for E cho Show 15, Tilt...
# 1  HP Laptop, 15.6" HD Touchscreen, AMD Athlon Go...

# %%
def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=[text],
        model=model,
    )
    return response.data[0].embedding

# %%
df_sample = df_items.sample(n=50, random_state=25)

data_to_embed = df_sample["preprocessed_data"].tolist()

pointstructs = []
for i, data in enumerate(data_to_embed):
    embedding = get_embedding(data)
    pointstruct = PointStruct(
        id=i,
        vector=embedding,
        payload={"text": data}
    )
    pointstructs.append(pointstruct)

# %%
qdrant_client.upsert(
    collection_name="Amazon-items-collection-02",
    wait=True,
    points=pointstructs
    )
# Out:
# UpdateResult(operation_id=0, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
import json
 
# asking about reason actually improves accuracy

output_schema = {
    "type": "array",
    "items": {
        "type": "object",
        "properties": {
            "question": {"type": "string", "description": "Suggested question to answer"},
            "chunk_ids": {
                "type": "array",
                "items": {
                    "type": "integer", 
                    "description": "Index of the chunk that could be used to answer the question"
                },
            },
            "answer_example": {"type": "string", "description": "Suggested answer grounded in the context."},
            "reasoning": {"type": "string", "description": "Reasoning why the answer could be answered with the available chunks."},
        }
    }
 }


SYSTEM_PROMPT = f"""
I am building a RAG application. I have a collection of 50 chunks of text.
The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have availabile.
I will provide all of the available products to you with indexes of each chunk.
I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
Also, provide an example answer the thee question given the context of the chunks.
Also, provide the reason why you chose the chunks to answer the questions. 
Try to have a mix of questions that could use multiple chunks and questions that could use single chunk.
Also, include 5 questions that can't be answered with the available chunks.

{json.dumps(output_schema, indent=2)}

I need to be able to parse the json output.

"""


USER_PROMPT = f"""
Here is the list of chunks, each list element is a dictionary with id and text.
{[{"id": i, "text": text} for i, text in enumerate(data_to_embed)]}
"""

print(SYSTEM_PROMPT)
# Out:
# I am building a RAG application. I have a collection of 50 chunks of text.
# The RAG application will act as a shopping assistant that can answer questions about the stock of the products we have availabile.
# I will provide all of the available products to you with indexes of each chunk.
# I want you to come up with 30 questions to which the answers could be grounded in the chunk context.
# As an output I need you to provide me the list of questions and the indexes of the chunks that could be used to answer them.
# Also, provide an example answer the thee question given the context of the chunks.
# Also, provide the reason why you chose the chunks to answer the questions.
# Try to have a mix of questions that could use multiple chunks and questions that could use single chunk.
# Also, include 5 questions that can't be answered with the available chunks.
#
# {
#   "type": "array",
#   "items": {
#     "type": "object",
#     "properties": {
#       "question": {
#         "type": "string",
#         "description": "Suggested question to answer"
#       },
#       "chunk_ids": {
#         "type": "array",
#         "items": {
#           "type": "integer",
#           "description": "Index of the chunk that could be used to answer the question"
#         }
#       },
#       "answer_example": {
#         "type": "string",
#         "description": "Suggested answer grounded in the context."
#       },
#       "reasoning": {
#         "type": "string",
#         "description": "Reasoning why the answer could be answered with the available chunks."
#       }
#     }
#   }
# }
#
# I need to be able to parse the json output.

# %%
from pprint import pprint

pprint(USER_PROMPT)

# %%
import openai
import os

response = openai.chat.completions.create(
    model="gpt-4.1",
    messages=[
        {"role": "system", "content": SYSTEM_PROMPT },
        {"role": "user", "content": USER_PROMPT}
    ]
)

print(response.choices[0].message.content)
# Out:
# ```json
# [
#   {
#     "question": "Do you have any security cameras in stock with 2K or higher resolution?",
#     "chunk_ids": [0, 13],
#     "answer_example": "Yes, we have the eufy security Floodlight Camera with 2K resolution and the REOLINK 4K Wired WiFi Outdoor Camera with 8MP (4K) resolution in stock.",
#     "reasoning": "Chunk 0 describes a 2K camera, and chunk 13 describes a 4K (8MP) camera, both fulfilling the requirement for high-resolution security cameras."
#   },
#   {
#     "question": "Are there any wireless earbuds with long battery life available?",
#     "chunk_ids": [1, 11, 24],
#     "answer_example": "Yes, we have several options: Wireless Earbuds that offer over 22 hours with the charging case (chunk 1), IKG Wireless Earbuds with up to 30 hours playtime (chunk 11), and Wireless Earbuds with a 2500mAh charging case providing more than 130 hours of music time (chunk 24).",
#     "reasoning": "Chunks 1, 11, and 24 all describe wireless earbuds, each with notable battery life."
#   },
#   {
#     "question": "Which iPad mini 6 cases do you have for kids?",
#     "chunk_ids": [6, 17, 36],
#     "answer_example": "We have multiple iPad Mini 6 cases for kids such as the OtterBox Made for Kids Case (chunk 6), a safe shockproof protection case with a handle and folding stand (chunk 17), and a LULULOOK Foldable Magnetic Stand designed for iPad Mini 6 (chunk 36).",
#     "reasoning": "Chunks 6 and 17 are specifically designed for iPad Mini 6 and for children; chunk 36 is a stand, which is also compatible with Mini 6."
#   },
#   {
#     "question": "Are there any tablet screen protectors compatible with Amazon Fire HD 10?",
#     "chunk_ids": [29],
#     "answer_example": "Yes, we have a 2 Pack Blue Light Screen Protector for Amazon Fire HD 10, Fire HD 10 Plus, Fire HD 10 Kids, and Fire HD 10 Kids Pro (chunk 29).",
#     "reasoning": "Chunk 29 details a protector specifically for those tablet models."
#   },
#   {
#     "question": "Do you stock adjustable TV mounts suitable for 65 inch TVs?",
#     "chunk_ids": [4],
#     "answer_example": "Yes, we offer the ELIVED Ceiling TV Mount that fits most 26-65 inch flat screen TVs with full motion height adjustment (chunk 4).",
#     "reasoning": "Chunk 4 mentions compatibility with up to 65 inch displays."
#   },
#   {
#     "question": "Are there any Bluetooth speakers with RGB lights?",
#     "chunk_ids": [9, 35, 23],
#     "answer_example": "We have the Fishcovers Computer Speakers featuring dynamic RGB lights (chunk 9), an RSHTECH RGB USB hub with 14 lighting modes for gaming setups (chunk 35), and portable Bluetooth speakers with multi-color lights and waterproof design (chunk 23).",
#     "reasoning": "Chunks 9 and 23 are Bluetooth speakers with RGB or multi-color lights. Chunk 35's RGB is for a USB hub, so only 9 and 23 are accurate for Bluetooth speakers."
#   },
#   {
#     "question": "Which products available are suitable for children's use or as kid gifts?",
#     "chunk_ids": [6, 7, 10, 17, 39, 45],
#     "answer_example": "Product options suitable for children include OtterBox Made for Kids iPad Mini 6 case (chunk 6), Ambison Push Popit Fidget Case for iPad 10.2 (chunk 7), a mixed pack of anime stickers (chunk 10), shockproof iPad Mini 6 case for kids (chunk 17), VuyKoo Cat Ear Bluetooth Headphones for kids (chunk 39), and Cute 3D Silicone AirPods Cases (chunk 45).",
#     "reasoning": "These chunks specify products as suitable for children or as child-friendly gifts."
#   },
#   {
#     "question": "Do you carry any fitness trackers or smartwatches for health monitoring?",
#     "chunk_ids": [14, 19],
#     "answer_example": "Yes, we have the IOWODO X5 Fitness Tracker Smartwatch with heart rate and sleep monitoring (chunk 14) and compatible Fitbit Luxe Bands for fitness tracking (chunk 19).",
#     "reasoning": "Chunk 14 is a full-featured fitness tracker; chunk 19 offers bands compatible with the Fitbit Luxe, which is a health tracker."
#   },
#   {
#     "question": "Can I get any laptop sleeves or bags compatible with MacBook Air/Pro 13-inch?",
#     "chunk_ids": [28],
#     "answer_example": "We offer the MOSISO Laptop Sleeve compatible with MacBook Air/Pro 13-13.3 inch and also MacBook Pro 14 inch models (chunk 28).",
#     "reasoning": "Chunk 28 specifies compatibility with MacBook Air/Pro 13-inch."
#   },
#   {
#     "question": "Which replacement ear tips are available for Beats earbuds?",
#     "chunk_ids": [34],
#     "answer_example": "We stock Rqker Ear Tips compatible with Beats Fit Pro and Studio Buds, available in 6 pairs with S/M/L sizes (chunk 34).",
#     "reasoning": "Chunk 34 describes replacement ear tips for Beats earbuds."
#   },
#   {
#     "question": "Are there any car-related accessories for Chevy or GMC trucks?",
#     "chunk_ids": [26, 48],
#     "answer_example": "Yes, we have a screen protector for GMC Sierra 1500 (chunk 26) and a short replacement radio antenna accessory for Chevy Silverado and GMC Sierra (chunk 48).",
#     "reasoning": "Both chunks clearly specify compatibility with Chevy and GMC automotive products."
#   },
#   {
#     "question": "Which products support both USB-A and USB-C connectivity?",
#     "chunk_ids": [35],
#     "answer_example": "The RSHTECH RGB 7 Ports USB 3.0/USB C Hub supports both USB-A and USB-C connections (chunk 35).",
#     "reasoning": "Chunk 35 mentions hybrid 2-in-1 cable (USB-A/USB-C)."
#   },
#   {
#     "question": "Is there any 3-in-1 fast charging cable for multiple device types?",
#     "chunk_ids": [40],
#     "answer_example": "Yes, we have a 4-pack 3-in-1 Multi Charging Cable with USB-C, Type C, and Micro USB port connectors (chunk 40).",
#     "reasoning": "Chunk 40 is a 3-in-1 charging cable."
#   },
#   {
#     "question": "Which products can help improve WiFi connectivity in my home?",
#     "chunk_ids": [30, 46],
#     "answer_example": "We offer a DG-Direct Wall Mount Holder for eero 6 and eero 6+ router mesh Wi-Fi systems (chunk 30) and the 2022 Newest WiFi Extender for extended signal coverage (chunk 46).",
#     "reasoning": "Chunk 30 is for WiFi mesh system accessories, chunk 46 is a WiFi extender."
#   },
#   {
#     "question": "Do you have any products specifically for protecting Samsung Galaxy tablets?",
#     "chunk_ids": [49],
#     "answer_example": "Yes, the kwmobile Case is compatible with the Samsung Galaxy Tab S7 FE, offering both protection and a stylish design (chunk 49).",
#     "reasoning": "Chunk 49 specifies compatibility with Samsung Galaxy Tab S7 FE."
#   },
#   {
#     "question": "Are there any accessories that help organize desk/cable clutter?",
#     "chunk_ids": [27, 31, 38],
#     "answer_example": "We have several solutions: WARRKY 4 Port USB Hub for laptops (chunk 27), DOXONN adjustable vertical laptop stand (chunk 31), and Bracwiser adjustable metal monitor riser and storage stand (chunk 38).",
#     "reasoning": "Each product addresses workspace organization: USB hub (27), laptop stand (31), monitor riser (38)."
#   },
#   {
#     "question": "Which wireless headphones are suitable for sports or workouts?",
#     "chunk_ids": [1, 11, 24, 42],
#     "answer_example": "Suitable wireless headphones for sports include Bluetooth 5.3 earbuds with secure fit for active lifestyles (chunk 1), IKG waterproof wireless earbuds (chunk 11), earbud headphones with earhooks for secure exercise fit (chunk 24), and klatre Open Ear Bone Conduction Headphones for running and cycling (chunk 42).",
#     "reasoning": "These chunks describe headphones/earbuds with features intended for fitness activities."
#   },
#   {
#     "question": "Can I find a wall or ceiling mount for a router or mesh Wi-Fi device?",
#     "chunk_ids": [30],
#     "answer_example": "Yes, the DG-Direct Wall Mount Holder is for eero 6 and eero 6+ router mesh Wi-Fi systems, making cable organization and placement simple (chunk 30).",
#     "reasoning": "Chunk 30 is about a wall mount for eero mesh routers."
#   },
#   {
#     "question": "Are there any waterproof protective storage cases for travel or outdoor use?",
#     "chunk_ids": [47],
#     "answer_example": "The Evergreen 57 Waterproof Dry Box Protective Case provides impact and waterproof protection suitable for cameras, phones, ammo, boating, and survival kits (chunk 47).",
#     "reasoning": "Chunk 47 describes a waterproof, impact-resistant case for multiple uses."
#   },
#   {
#     "question": "Do you offer screen protectors for vehicles?",
#     "chunk_ids": [26],
#     "answer_example": "Yes, we have a screen protector for the 2022–2023 GMC Sierra 1500 SLE Elevation and SLT model instrument panels (chunk 26).",
#     "reasoning": "Chunk 26 specifically mentions a product for GMC vehicle screen protection."
#   },
#   {
#     "question": "Which products are designed for both iPhone charging and audio output?",
#     "chunk_ids": [3, 18, 25, 44],
#     "answer_example": "Options include 5-pack MFi Certified iPhone Lightning cables (chunk 3); ORICO USB-A to Lightning Cable with LED Display (chunk 18); Lightning to 3.5mm Aux Cord for iPhone (chunk 25); and a 2-pack headphone adapter for iPhone that enables both charging and audio (chunk 44).",
#     "reasoning": "Chunks 3, 18, 25, and 44 all describe cables/adapters for iPhone charging and/or audio."
#   },
#   {
#     "question": "Are there any power adapters or chargers for use with SFP modules or similar networking equipment?",
#     "chunk_ids": [5],
#     "answer_example": "We have the TP-Link TL-SM331T 1000Base-T RJ45 SFP Module for connecting SFP interface to Ethernet gigabit ports, no specific power adapter needed as it is hot pluggable (chunk 5).",
#     "reasoning": "Chunk 5 is about an SFP transceiver module."
#   },
#   {
#     "question": "Do you have any soundbars for TVs?",
#     "chunk_ids": [32],
#     "answer_example": "Yes, we stock the Bose Solo 5 TV Sound System with Universal Remote Control (chunk 32).",
#     "reasoning": "Chunk 32 describes a TV sound system/soundbar."
#   },
#   {
#     "question": "Which products are specifically designed for laptops or computers?",
#     "chunk_ids": [2, 28, 31, 38, 27, 35],
#     "answer_example": "Options for laptops and desktops include the Lenovo Ideapad 3 laptop (chunk 2), MOSISO laptop sleeve (chunk 28), DOXONN vertical laptop holder (chunk 31), Bracwiser foldable monitor riser (chunk 38), WARRKY 4-port USB hub (chunk 27), and RSHTECH RGB powered USB hub (chunk 35).",
#     "reasoning": "These chunks all describe products explicitly for laptops/computers."
#   },
#   {
#     "question": "Can I find a camera with two-way talk feature?",
#     "chunk_ids": [20],
#     "answer_example": "Yes, the Kocanasi Light Bulb Security Camera offers two-way talk capability (chunk 20).",
#     "reasoning": "Chunk 20 lists two-way talk in its product description."
#   },
#   {
#     "question": "Is there a car charger or charging dock for specific devices?",
#     "chunk_ids": [22],
#     "answer_example": "Yes, the Rose Charger is a standing magnetic fast-charging USB cable compatible with most rose-shaped personal devices and can be used with car chargers (chunk 22).",
#     "reasoning": "Chunk 22 mentions use with car chargers."
#   },
#   {
#     "question": "Do you have any products with USB, HDMI, or SD card ports for data transfer?",
#     "chunk_ids": [2, 43, 27, 35],
#     "answer_example": "The Lenovo Ideapad 3 Laptop comes with USB 3.2, HDMI, and SD card ports (chunk 2). The Lenovo Ideapad 1i also has HDMI and USB (chunk 43). WARRKY and RSHTECH USB hubs (chunks 27 and 35) expand USB connectivity.",
#     "reasoning": "Chunks 2 and 43 describe laptops with these ports; 27 and 35 are USB hubs."
#   },
#   {
#     "question": "Do you have any waterproof headphones or earbuds?",
#     "chunk_ids": [11, 24, 39, 42],
#     "answer_example": "We have IKG Wireless Earbuds (IPX7 waterproof, chunk 11), over-ear wireless earbuds rated at IPX7 (chunk 24), VuyKoo Cat Ear Kids Bluetooth Headphones (chunk 39), and klatre bone conduction headphones for sports (chunk 42), all waterproof.",
#     "reasoning": "These describe headphones/earbuds with waterproofing."
#   },
#   {
#     "question": "Which products are suitable for MacBook Pro 14 inch?",
#     "chunk_ids": [28],
#     "answer_example": "The MOSISO Laptop Sleeve is compatible with MacBook Pro 14 inch (chunk 28).",
#     "reasoning": "Chunk 28 lists MacBook Pro 14 inch compatibility."
#   },
#   {
#     "question": "Are there any products with parental controls or child usage limitations?",
#     "chunk_ids": [],
#     "answer_example": "Sorry, none of our available products specify parental controls or child usage limitations.",
#     "reasoning": "No chunk discusses parental controls or restrictions."
#   },
#   {
#     "question": "Is there any Apple Watch in stock?",
#     "chunk_ids": [],
#     "answer_example": "No, we do not currently stock any Apple Watch devices.",
#     "reasoning": "No chunk is about the Apple Watch."
#   },
#   {
#     "question": "Can I buy a refrigerator or kitchen appliance from you?",
#     "chunk_ids": [],
#     "answer_example": "Currently, we do not have any refrigerators or kitchen appliances in stock.",
#     "reasoning": "No chunk describes refrigerators or kitchen appliances."
#   },
#   {
#     "question": "Do you offer streaming sticks or smart TV boxes?",
#     "chunk_ids": [],
#     "answer_example": "We do not offer streaming sticks or smart TV boxes at the moment.",
#     "reasoning": "No chunk describes streaming sticks or TV boxes."
#   },
#   {
#     "question": "Do you have any home printers or ink cartridges?",
#     "chunk_ids": [],
#     "answer_example": "We do not offer printers or ink cartridges in our product selection at this time.",
#     "reasoning": "No chunk is about printers or ink."
#   }
# ]
# ```

# %%
json_output = response.choices[0].message.content
json_output = json_output.replace("```json", "").replace("```", "")
json_output = json.loads(json_output)

# %%
json_output
# Out:
# [{'question': 'Do you have any security cameras in stock with 2K or higher resolution?',
#   'chunk_ids': [0, 13],
#   'answer_example': 'Yes, we have the eufy security Floodlight Camera with 2K resolution and the REOLINK 4K Wired WiFi Outdoor Camera with 8MP (4K) resolution in stock.',
#   'reasoning': 'Chunk 0 describes a 2K camera, and chunk 13 describes a 4K (8MP) camera, both fulfilling the requirement for high-resolution security cameras.'},
#  {'question': 'Are there any wireless earbuds with long battery life available?',
#   'chunk_ids': [1, 11, 24],
#   'answer_example': 'Yes, we have several options: Wireless Earbuds that offer over 22 hours with the charging case (chunk 1), IKG Wireless Earbuds with up to 30 hours playtime (chunk 11), and Wireless Earbuds with a 2500mAh charging case providing more than 130 hours of music time (chunk 24).',
#   'reasoning': 'Chunks 1, 11, and 24 all describe wireless earbuds, each with notable battery life.'},
#  {'question': 'Which iPad mini 6 cases do you have for kids?',
#   'chunk_ids': [6, 17, 36],
#   'answer_example': 'We have multiple iPad Mini 6 cases for kids such as the OtterBox Made for Kids Case (chunk 6), a safe shockproof protection case with a handle and folding stand (chunk 17), and a LULULOOK Foldable Magnetic Stand designed for iPad Mini 6 (chunk 36).',
#   'reasoning': 'Chunks 6 and 17 are specifically designed for iPad Mini 6 and for children; chunk 36 is a stand, which is also compatible with Mini 6.'},
#  {'question': 'Are there any tablet screen protectors compatible with Amazon Fire HD 10?',
#   'chunk_ids': [29],
#   'answer_example': 'Yes, we have a 2 Pack Blue Light Screen Protector for Amazon Fire HD 10, Fire HD 10 Plus, Fire HD 10 Kids, and Fire HD 10 Kids Pro (chunk 29).',
#   'reasoning': 'Chunk 29 details a protector specifically for those tablet models.'},
#  {'question': 'Do you stock adjustable TV mounts suitable for 65 inch TVs?',
#   'chunk_ids': [4],
#   'answer_example': 'Yes, we offer the ELIVED Ceiling TV Mount that fits most 26-65 inch flat screen TVs with full motion height adjustment (chunk 4).',
#   'reasoning': 'Chunk 4 mentions compatibility with up to 65 inch displays.'},
#  {'question': 'Are there any Bluetooth speakers with RGB lights?',
#   'chunk_ids': [9, 35, 23],
#   'answer_example': 'We have the Fishcovers Computer Speakers featuring dynamic RGB lights (chunk 9), an RSHTECH RGB USB hub with 14 lighting modes for gaming setups (chunk 35), and portable Bluetooth speakers with multi-color lights and waterproof design (chunk 23).',
#   'reasoning': "Chunks 9 and 23 are Bluetooth speakers with RGB or multi-color lights. Chunk 35's RGB is for a USB hub, so only 9 and 23 are accurate for Bluetooth speakers."},
#  {'question': "Which products available are suitable for children's use or as kid gifts?",
#   'chunk_ids': [6, 7, 10, 17, 39, 45],
#   'answer_example': 'Product options suitable for children include OtterBox Made for Kids iPad Mini 6 case (chunk 6), Ambison Push Popit Fidget Case for iPad 10.2 (chunk 7), a mixed pack of anime stickers (chunk 10), shockproof iPad Mini 6 case for kids (chunk 17), VuyKoo Cat Ear Bluetooth Headphones for kids (chunk 39), and Cute 3D Silicone AirPods Cases (chunk 45).',
#   'reasoning': 'These chunks specify products as suitable for children or as child-friendly gifts.'},
#  {'question': 'Do you carry any fitness trackers or smartwatches for health monitoring?',
#   'chunk_ids': [14, 19],
#   'answer_example': 'Yes, we have the IOWODO X5 Fitness Tracker Smartwatch with heart rate and sleep monitoring (chunk 14) and compatible Fitbit Luxe Bands for fitness tracking (chunk 19).',
#   'reasoning': 'Chunk 14 is a full-featured fitness tracker; chunk 19 offers bands compatible with the Fitbit Luxe, which is a health tracker.'},
#  {'question': 'Can I get any laptop sleeves or bags compatible with MacBook Air/Pro 13-inch?',
#   'chunk_ids': [28],
#   'answer_example': 'We offer the MOSISO Laptop Sleeve compatible with MacBook Air/Pro 13-13.3 inch and also MacBook Pro 14 inch models (chunk 28).',
#   'reasoning': 'Chunk 28 specifies compatibility with MacBook Air/Pro 13-inch.'},
#  {'question': 'Which replacement ear tips are available for Beats earbuds?',
#   'chunk_ids': [34],
#   'answer_example': 'We stock Rqker Ear Tips compatible with Beats Fit Pro and Studio Buds, available in 6 pairs with S/M/L sizes (chunk 34).',
#   'reasoning': 'Chunk 34 describes replacement ear tips for Beats earbuds.'},
#  {'question': 'Are there any car-related accessories for Chevy or GMC trucks?',
#   'chunk_ids': [26, 48],
#   'answer_example': 'Yes, we have a screen protector for GMC Sierra 1500 (chunk 26) and a short replacement radio antenna accessory for Chevy Silverado and GMC Sierra (chunk 48).',
#   'reasoning': 'Both chunks clearly specify compatibility with Chevy and GMC automotive products.'},
#  {'question': 'Which products support both USB-A and USB-C connectivity?',
#   'chunk_ids': [35],
#   'answer_example': 'The RSHTECH RGB 7 Ports USB 3.0/USB C Hub supports both USB-A and USB-C connections (chunk 35).',
#   'reasoning': 'Chunk 35 mentions hybrid 2-in-1 cable (USB-A/USB-C).'},
#  {'question': 'Is there any 3-in-1 fast charging cable for multiple device types?',
#   'chunk_ids': [40],
#   'answer_example': 'Yes, we have a 4-pack 3-in-1 Multi Charging Cable with USB-C, Type C, and Micro USB port connectors (chunk 40).',
#   'reasoning': 'Chunk 40 is a 3-in-1 charging cable.'},
#  {'question': 'Which products can help improve WiFi connectivity in my home?',
#   'chunk_ids': [30, 46],
#   'answer_example': 'We offer a DG-Direct Wall Mount Holder for eero 6 and eero 6+ router mesh Wi-Fi systems (chunk 30) and the 2022 Newest WiFi Extender for extended signal coverage (chunk 46).',
#   'reasoning': 'Chunk 30 is for WiFi mesh system accessories, chunk 46 is a WiFi extender.'},
#  {'question': 'Do you have any products specifically for protecting Samsung Galaxy tablets?',
#   'chunk_ids': [49],
#   'answer_example': 'Yes, the kwmobile Case is compatible with the Samsung Galaxy Tab S7 FE, offering both protection and a stylish design (chunk 49).',
#   'reasoning': 'Chunk 49 specifies compatibility with Samsung Galaxy Tab S7 FE.'},
#  {'question': 'Are there any accessories that help organize desk/cable clutter?',
#   'chunk_ids': [27, 31, 38],
#   'answer_example': 'We have several solutions: WARRKY 4 Port USB Hub for laptops (chunk 27), DOXONN adjustable vertical laptop stand (chunk 31), and Bracwiser adjustable metal monitor riser and storage stand (chunk 38).',
#   'reasoning': 'Each product addresses workspace organization: USB hub (27), laptop stand (31), monitor riser (38).'},
#  {'question': 'Which wireless headphones are suitable for sports or workouts?',
#   'chunk_ids': [1, 11, 24, 42],
#   'answer_example': 'Suitable wireless headphones for sports include Bluetooth 5.3 earbuds with secure fit for active lifestyles (chunk 1), IKG waterproof wireless earbuds (chunk 11), earbud headphones with earhooks for secure exercise fit (chunk 24), and klatre Open Ear Bone Conduction Headphones for running and cycling (chunk 42).',
#   'reasoning': 'These chunks describe headphones/earbuds with features intended for fitness activities.'},
#  {'question': 'Can I find a wall or ceiling mount for a router or mesh Wi-Fi device?',
#   'chunk_ids': [30],
#   'answer_example': 'Yes, the DG-Direct Wall Mount Holder is for eero 6 and eero 6+ router mesh Wi-Fi systems, making cable organization and placement simple (chunk 30).',
#   'reasoning': 'Chunk 30 is about a wall mount for eero mesh routers.'},
#  {'question': 'Are there any waterproof protective storage cases for travel or outdoor use?',
#   'chunk_ids': [47],
#   'answer_example': 'The Evergreen 57 Waterproof Dry Box Protective Case provides impact and waterproof protection suitable for cameras, phones, ammo, boating, and survival kits (chunk 47).',
#   'reasoning': 'Chunk 47 describes a waterproof, impact-resistant case for multiple uses.'},
#  {'question': 'Do you offer screen protectors for vehicles?',
#   'chunk_ids': [26],
#   'answer_example': 'Yes, we have a screen protector for the 2022–2023 GMC Sierra 1500 SLE Elevation and SLT model instrument panels (chunk 26).',
#   'reasoning': 'Chunk 26 specifically mentions a product for GMC vehicle screen protection.'},
#  {'question': 'Which products are designed for both iPhone charging and audio output?',
#   'chunk_ids': [3, 18, 25, 44],
#   'answer_example': 'Options include 5-pack MFi Certified iPhone Lightning cables (chunk 3); ORICO USB-A to Lightning Cable with LED Display (chunk 18); Lightning to 3.5mm Aux Cord for iPhone (chunk 25); and a 2-pack headphone adapter for iPhone that enables both charging and audio (chunk 44).',
#   'reasoning': 'Chunks 3, 18, 25, and 44 all describe cables/adapters for iPhone charging and/or audio.'},
#  {'question': 'Are there any power adapters or chargers for use with SFP modules or similar networking equipment?',
#   'chunk_ids': [5],
#   'answer_example': 'We have the TP-Link TL-SM331T 1000Base-T RJ45 SFP Module for connecting SFP interface to Ethernet gigabit ports, no specific power adapter needed as it is hot pluggable (chunk 5).',
#   'reasoning': 'Chunk 5 is about an SFP transceiver module.'},
#  {'question': 'Do you have any soundbars for TVs?',
#   'chunk_ids': [32],
#   'answer_example': 'Yes, we stock the Bose Solo 5 TV Sound System with Universal Remote Control (chunk 32).',
#   'reasoning': 'Chunk 32 describes a TV sound system/soundbar.'},
#  {'question': 'Which products are specifically designed for laptops or computers?',
#   'chunk_ids': [2, 28, 31, 38, 27, 35],
#   'answer_example': 'Options for laptops and desktops include the Lenovo Ideapad 3 laptop (chunk 2), MOSISO laptop sleeve (chunk 28), DOXONN vertical laptop holder (chunk 31), Bracwiser foldable monitor riser (chunk 38), WARRKY 4-port USB hub (chunk 27), and RSHTECH RGB powered USB hub (chunk 35).',
#   'reasoning': 'These chunks all describe products explicitly for laptops/computers.'},
#  {'question': 'Can I find a camera with two-way talk feature?',
#   'chunk_ids': [20],
#   'answer_example': 'Yes, the Kocanasi Light Bulb Security Camera offers two-way talk capability (chunk 20).',
#   'reasoning': 'Chunk 20 lists two-way talk in its product description.'},
#  {'question': 'Is there a car charger or charging dock for specific devices?',
#   'chunk_ids': [22],
#   'answer_example': 'Yes, the Rose Charger is a standing magnetic fast-charging USB cable compatible with most rose-shaped personal devices and can be used with car chargers (chunk 22).',
#   'reasoning': 'Chunk 22 mentions use with car chargers.'},
#  {'question': 'Do you have any products with USB, HDMI, or SD card ports for data transfer?',
#   'chunk_ids': [2, 43, 27, 35],
#   'answer_example': 'The Lenovo Ideapad 3 Laptop comes with USB 3.2, HDMI, and SD card ports (chunk 2). The Lenovo Ideapad 1i also has HDMI and USB (chunk 43). WARRKY and RSHTECH USB hubs (chunks 27 and 35) expand USB connectivity.',
#   'reasoning': 'Chunks 2 and 43 describe laptops with these ports; 27 and 35 are USB hubs.'},
#  {'question': 'Do you have any waterproof headphones or earbuds?',
#   'chunk_ids': [11, 24, 39, 42],
#   'answer_example': 'We have IKG Wireless Earbuds (IPX7 waterproof, chunk 11), over-ear wireless earbuds rated at IPX7 (chunk 24), VuyKoo Cat Ear Kids Bluetooth Headphones (chunk 39), and klatre bone conduction headphones for sports (chunk 42), all waterproof.',
#   'reasoning': 'These describe headphones/earbuds with waterproofing.'},
#  {'question': 'Which products are suitable for MacBook Pro 14 inch?',
#   'chunk_ids': [28],
#   'answer_example': 'The MOSISO Laptop Sleeve is compatible with MacBook Pro 14 inch (chunk 28).',
#   'reasoning': 'Chunk 28 lists MacBook Pro 14 inch compatibility.'},
#  {'question': 'Are there any products with parental controls or child usage limitations?',
#   'chunk_ids': [],
#   'answer_example': 'Sorry, none of our available products specify parental controls or child usage limitations.',
#   'reasoning': 'No chunk discusses parental controls or restrictions.'},
#  {'question': 'Is there any Apple Watch in stock?',
#   'chunk_ids': [],
#   'answer_example': 'No, we do not currently stock any Apple Watch devices.',
#   'reasoning': 'No chunk is about the Apple Watch.'},
#  {'question': 'Can I buy a refrigerator or kitchen appliance from you?',
#   'chunk_ids': [],
#   'answer_example': 'Currently, we do not have any refrigerators or kitchen appliances in stock.',
#   'reasoning': 'No chunk describes refrigerators or kitchen appliances.'},
#  {'question': 'Do you offer streaming sticks or smart TV boxes?',
#   'chunk_ids': [],
#   'answer_example': 'We do not offer streaming sticks or smart TV boxes at the moment.',
#   'reasoning': 'No chunk describes streaming sticks or TV boxes.'},
#  {'question': 'Do you have any home printers or ink cartridges?',
#   'chunk_ids': [],
#   'answer_example': 'We do not offer printers or ink cartridges in our product selection at this time.',
#   'reasoning': 'No chunk is about printers or ink.'}]

# %%
from langsmith import Client
import os

lc_client = Client(api_key=os.getenv("LANGSMITH_API_KEY"))

# %%
dataset_name = "rag-evaluation-dataset"
dataset = lc_client.create_dataset(
    dataset_name=dataset_name,
    description="Dataset for evaluating RAG systems",
)

# %%
for item in json_output:
    lc_client.create_example(
        dataset_id=dataset.id,
        inputs={"question": item["question"]},
        outputs={
            'ground_truth': item["answer_example"],
            'context_ids': item["chunk_ids"],
            'contexts': [qdrant_client.retrieve(
                collection_name="Amazon-items-collection-02", 
                ids=[id],
                with_payload=True)[0].payload['text'] for id in item["chunk_ids"]
            ]
        }
    )

# %%
len(json_output)
# Out:
# 34

# %%
import asyncio

async def foo():
    print("Start foo")
    await asyncio.sleep(1)
    print("Koniec foo")

async def bar():
    print("Start bar")
    await asyncio.sleep(2)
    print("Koniec bar")

await asyncio.gather(foo(), bar())
print("Koniec main")
# Out:
# Start foo
# Start bar
# Koniec foo
# Koniec bar
# Koniec main
