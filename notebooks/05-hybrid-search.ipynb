# %%
print("Hello World")
# Out:
# Hello World

# %%
from qdrant_client import QdrantClient
from qdrant_client.models import Distance, VectorParams, PointStruct, PayloadSchemaType
import pandas as pd

# %%
df_items = pd.read_json("../data/meta_Electronics_1000.jsonl", lines=True)

df_items.head(3)
# Out:
#      main_category                                              title  \
# 0  All Electronics  Adjustable Metal Stand for E cho Show 15, Tilt...
# 1        Computers  HP Laptop, 15.6" HD Touchscreen, AMD Athlon Go...
# 2      Amazon Home  50 Pcs Groot Stickers for Water Bottle Waterpr...
#
#    average_rating  rating_number  \
# 0             4.5            111
# 1             4.4            205
# 2             4.7            156
#
#                                             features  \
# 0  [The VMEI adjustable metal bracket is made of ...
# 1  [【High Speed RAM And Enormous Space】8GB high-b...
# 2  [🏆Groot Stickers:Anime theme party favors for ...
#
#                                          description  price  \
# 0                                                 []  36.99
# 1  [PConline365 sells computers with professional...    NaN
# 2  [Groot Stickers Quantity: 50 Pcs/pack.Non-dupl...   5.99
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
# 2  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos    store  \
# 0  [{'title': 'Small footprint, minimalist design...     VMEI
# 1                                                 []       HP
# 2  [{'title': '200-Piece Stickers Pack for Laptop...  Fcelery
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
# 2  [Electronics, Computers & Accessories, Laptop ...
#
#                                              details parent_asin  \
# 0  {'Brand': 'VMEI', 'Color': 'Black', 'Room Type...  B0B13T2GY5
# 1  {'Brand': 'HP', 'Color': 'Silver', 'Room Type'...  B08DC5KLJZ
# 2  {'Brand': 'Fcelery', 'Color': 'Groot', 'Room T...  B0B4QQSRY3
#
#    bought_together available_date
# 0              NaN     2022-05-11
# 1              NaN     2022-03-24
# 2              NaN     2022-06-22

# %%
def preprocess_data(row):
    return f"{row['title']} {' '.join(row['features'])}"

# %%
def extract_first_large_image(row):
    return row["images"][0].get("large", '')

# %%
df_items["preprocessed_data"] = df_items.apply(preprocess_data, axis=1)
df_items["first_large_image"] = df_items.apply(extract_first_large_image, axis=1)

# %%
df_items.head(2)
# Out:
#      main_category                                              title  \
# 0  All Electronics  Adjustable Metal Stand for E cho Show 15, Tilt...
# 1        Computers  HP Laptop, 15.6" HD Touchscreen, AMD Athlon Go...
#
#    average_rating  rating_number  \
# 0             4.5            111
# 1             4.4            205
#
#                                             features  \
# 0  [The VMEI adjustable metal bracket is made of ...
# 1  [【High Speed RAM And Enormous Space】8GB high-b...
#
#                                          description  price  \
# 0                                                 []  36.99
# 1  [PConline365 sells computers with professional...    NaN
#
#                                               images  \
# 0  [{'thumb': 'https://m.media-amazon.com/images/...
# 1  [{'thumb': 'https://m.media-amazon.com/images/...
#
#                                               videos store  \
# 0  [{'title': 'Small footprint, minimalist design...  VMEI
# 1                                                 []    HP
#
#                                           categories  \
# 0  [Electronics, Computers & Accessories, Compute...
# 1  [Electronics, Computers & Accessories, Compute...
#
#                                              details parent_asin  \
# 0  {'Brand': 'VMEI', 'Color': 'Black', 'Room Type...  B0B13T2GY5
# 1  {'Brand': 'HP', 'Color': 'Silver', 'Room Type'...  B08DC5KLJZ
#
#    bought_together available_date  \
# 0              NaN     2022-05-11
# 1              NaN     2022-03-24
#
#                                    preprocessed_data  \
# 0  Adjustable Metal Stand for E cho Show 15, Tilt...
# 1  HP Laptop, 15.6" HD Touchscreen, AMD Athlon Go...
#
#                                    first_large_image
# 0  https://m.media-amazon.com/images/I/415fkdvFA9...
# 1  https://m.media-amazon.com/images/I/41oJoaJ+Vw...

# %%
qdrant_client = QdrantClient(
    url="http://localhost:6333",
)

# %%
qdrant_client.create_collection(
    collection_name="Amazon-items-collection-01-hybrid",
    vectors_config=VectorParams(size=1536, distance=Distance.COSINE),
)
# Out:
# True

# %%
qdrant_client.create_payload_index(
    collection_name="Amazon-items-collection-01-hybrid",
    field_name="text",
    field_schema=PayloadSchemaType.TEXT
)
# Out:
# UpdateResult(operation_id=1, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
df_sample = df_items.sample(n=50, random_state=25)

# %%
import openai

def get_embedding(text, model="text-embedding-3-small"):
    response = openai.embeddings.create(
        input=[text],
        model=model,
    )
    return response.data[0].embedding

# %%
data_to_embed = df_sample[["preprocessed_data", "first_large_image", "rating_number", "price", "average_rating"]].to_dict(orient="records")

# %%
data_to_embed

# %%
pointstructs = []
for i, data in enumerate(data_to_embed):
    embedding = get_embedding(data['preprocessed_data'])
    pointstructs.append(PointStruct(
        id=i,
        vector=embedding,
        payload={
            "text": data['preprocessed_data'],
            "first_large_image": data['first_large_image'],
            "average_rating": data['average_rating'],
            "rating_number": data['rating_number'],
            "price": data['price'],
        }
    ))

# %%
pointstructs[1]
# Out:
# PointStruct(id=1, vector=[-0.007936007343232632, 0.014085295610129833, -0.058763179928064346, -0.017519764602184296, -0.03134698048233986, -0.03083081543445587, 0.011802266351878643, 0.03952617943286896, 0.023187631741166115, -0.022433239966630936, 0.006461964454501867, 0.0071319835260510445, -0.06995994597673416, 0.004573502577841282, 0.029758784919977188, 0.021301651373505592, -0.06182045117020607, -0.026919888332486153, -0.02275087870657444, -0.001864887191914022, 0.028805868700146675, 0.03386823832988739, 0.01878039352595806, 0.014452565461397171, -0.011127284727990627, 0.006610857788473368, -0.0010279833804816008, 0.022909699007868767, -0.013420239090919495, -0.021381061524152756, -0.007553847972303629, -0.0006991776172071695, 0.056301478296518326, -0.029957309365272522, -0.017767921090126038, -0.014263967052102089, 0.03146609291434288, -0.054078005254268646, 0.031962405890226364, -0.04411209002137184, 0.04768552631139755, 0.012278725393116474, 0.020567111670970917, 0.029024245217442513, -0.020021170377731323, 0.007945933379232883, -0.048519328236579895, 0.018968991935253143, 0.010779866948723793, 0.04256359860301018, -0.03712403401732445, 0.03404691070318222, -0.029083803296089172, 0.07420836389064789, -0.0068838284350931644, 0.027396347373723984, 0.001460394007153809, 0.04169009253382683, -0.008323129266500473, -0.007087315898388624, -0.030076423659920692, 0.016507292166352272, 0.0047695450484752655, 0.06559241563081741, -0.05685734376311302, -0.02894483506679535, -0.012626142241060734, 0.02076563611626625, -0.0438738577067852, -0.006938422564417124, 0.03005657158792019, -0.02140091359615326, -0.046573787927627563, -0.015067990869283676, 0.005434601567685604, 0.010075105354189873, 0.012914002873003483, -0.05808819457888603, -0.0020584482699632645, 0.012377986684441566, -0.013588985428214073, 0.01125632505863905, -0.03593289107084274, 0.02461700700223446, -0.05078250169754028, -0.023584680631756783, -0.06444097310304642, -0.038156360387802124, -0.0520530603826046, -0.0033798753283917904, -0.023783205077052116, -0.03597259521484375, 0.01772821508347988, -0.017460208386182785, -0.014730499126017094, 0.03408661484718323, 0.0248552355915308, 0.028051476925611496, 0.0022768250200897455, 0.02684047818183899, 0.053839776664972305, -0.009980807080864906, -0.02783310040831566, -0.024696417152881622, 0.02578829973936081, -0.0027793394401669502, 0.0019095551688224077, 0.009385233744978905, -0.024656711146235466, 0.04065776616334915, 0.0020299104508012533, -0.009221451357007027, 0.010720309801399708, -0.016159873455762863, -0.011980938725173473, 0.00656618969514966, 0.017579322680830956, -0.023525124415755272, -0.013112526386976242, 0.028210295364260674, 0.013112526386976242, 0.02298910915851593, 0.006203882861882448, -0.03224033862352371, 0.024517744779586792, -0.019723383709788322, 0.0013028153916820884, -0.022969255223870277, -0.030731553211808205, -0.009831913746893406, -0.0391688346862793, 0.03492041677236557, 0.06980112940073013, -0.001624176511541009, -0.023584680631756783, -0.030135981738567352, -0.01084935013204813, 0.052092764526605606, 0.007891339249908924, -0.035476282238960266, 0.00869039911776781, -0.04701054096221924, 0.04216654971241951, -0.001825182349421084, 0.008928628638386726, -0.01050193328410387, 0.05165601149201393, -0.03712403401732445, -0.03615126758813858, 0.053958892822265625, -0.02650298736989498, 0.005275782197713852, -0.01954471319913864, 0.031148454174399376, 0.07500246167182922, -0.006223735399544239, 0.023584680631756783, 0.0643218606710434, -0.03648875653743744, -0.025530219078063965, -0.01753961853682995, 0.042722418904304504, -0.03621082380414009, -0.02100386656820774, 0.03853355720639229, 0.020725931972265244, 0.020487703382968903, 0.028587492182850838, -0.035297613590955734, -0.010372892022132874, 0.03263738751411438, -0.027972066774964333, -0.016417955979704857, 0.024478040635585785, 0.02140091359615326, -0.062018975615501404, 0.02007080242037773, 0.007727556396275759, 0.002269380260258913, -0 ...

# %%
qdrant_client.upsert(
    collection_name="Amazon-items-collection-01-hybrid",
    points=pointstructs,
    wait=True
)
# Out:
# UpdateResult(operation_id=6, status=<UpdateStatus.COMPLETED: 'completed'>)

# %%
from qdrant_client.models import Prefetch, Filter, FieldCondition, MatchText, FusionQuery

def retrieve_data(query, k=5):
    query_embedding = get_embedding(query)

    results = qdrant_client.query_points(
        collection_name="Amazon-items-collection-01-hybrid",
        prefetch=[
            Prefetch(
                query=query_embedding,
                limit=20,
            ),
            Prefetch(
                filter=Filter(
                    must=[
                        FieldCondition(
                            key="text",
                            match=MatchText(
                                text=query,
                            )
                        )
                    ]
                ),
                limit=20
            )
        ],
        query=FusionQuery(fusion="rrf"),
        limit=k,
    )
    return results

# %%
retrieve_data("earphones", k=5).points
# Out:
# [ScoredPoint(id=11, version=6, score=0.8333334, payload={'text': 'IKG Wireless Earbuds, Bluetooth Headphones with Microphone, 30H Playtime with Transparent Charging Case, Deep Bass, IPX7 Waterproof, Earphones for Work Sport Game Ergonomic design and unique appearance: the weight of a single earbud is only 3.5g, round and smooth sound cavity design, 35 ° of the golden angle of entry into the ear, the curve of the body design of the fit to provide a good airtightness. Headphones wireless unique transparent cover and simple charging compartment design, easily adapt to different scenarios. Bluetooth 5.3 and automatic one-step connection: The in-ear headphones provide simultaneous binaural transmission through the use of Bluetooth 5.3 chip, increasing the connection speed by 80%. Dual-channel transmission technology for seamless switching between single/binaural modes. By opening the lid of the charging case, the Bluetooth headset can automatically connect to the previously paired device. Subwoofer and CVC8.0: The headset speaker uses a 13.4mm composite diaphragm with a large dynamic coil to create a spatial 3D panoramic sound effect, earbuds wirelessly improve sound quality by 90%, and support for audio HD decoding and CVC8.0 lets you enjoy clear calls. Equipped with an optical infrared sensor to support in-ear recognition. Touch operation, IPX7 waterproof: Wireless headphones can easily control volume, songs, calls and voice assistants with a simple touch of a finger on the side of the headphone shaft, and the controls can be used completely off the phone. IPX7 waterproof earbuds, rain and sweat resistant, BTW86 wireless earbuds are a great helper when playing sports. Type-C fast charging, 30 hours of life: The wireless headphone charging case is equipped with a Type-C charging port, which increases the charging speed by 2 times and can be easily charged in 10 minutes and used for 1 hour. The headphones and charging case can last up to 30 hours.', 'first_large_image': 'https://m.media-amazon.com/images/I/21GgmlovxUL._AC_.jpg', 'average_rating': 4.9, 'rating_number': 238, 'price': 29.99}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=1, version=6, score=0.8333334, payload={'text': 'Wireless Earbuds Bluetooth 5.3 Headphones Deep Bass in-Ear Earphones Premium Sound with Mic Wireless Charging Case for iPhone, Samsung, Android Smartphone Laptop Sports [Advanced Bluetooth Technology] Our earbuds adopt Bluetooth 5.3 technology, which greatly improves the transmission speed and provides a low-latency listening experience. With support for A2DP, AVRCP, HFP, and more, you can enjoy seamless connectivity and superb audio quality. [Enhanced Audio Experience] Immerse yourself in powerful, deep bass with our wireless earbuds. Designed to provide extra punch, warmth, and impact to keep you energized during your workout and deliver crystal-clear sound for a superior listening experience. [Long Battery Life] Enjoy up to 5 hours of playback time per earbud, and a total of over 22 hours (100% volume) when combined with the charging case. Enjoy a full day of listening enjoyment with just 1.5 hours of charging time. Charge easily with the included charging case and Type-C charging cable. [Comfortable and Secure Fit] Designed with a slim profile and a longer earbud stem, our wireless earbuds offer a more snug in-ear fit. This creates a perfect seal, improves sound quality, and ensures a comfortable and secure fit, making them ideal for active lifestyles and sports activities. [Convenient Touch Control] Our wireless earbuds have a smart touch control function, you can easily play/pause music, skip songs, activate voice assistant, and answer calls with just a tap of the earbuds. With the built-in microphone, you can experience clear calls even in noisy environments, and easily activate Siri or Google Assistant.', 'first_large_image': 'https://m.media-amazon.com/images/I/31gkLMAxpWL._AC_.jpg', 'average_rating': 4.5, 'rating_number': 3417, 'price': 17.99}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=24, version=6, score=0.5, payload={'text': 'Wireless Earbuds Bluetooth Headphones 130Hrs Playtime with 2500mAh Wireless Charging Case LED Diaplay Hi-Fi Waterproof Over Ear Earphones for Sports Running Workout Gaming Wireless Charging Case with LED Display: 2500mAh charging case supports 16 times fully charging for wireless earbuds and let you enjoy more than 130 hours music time. Each earbud can get 8hrs playback on a single charge. Charging case can charge your phone as an emergency power bank. The case is compatible with Type-c and wireless charger. LED power display shows the charging status of earbuds and charging case. Hi-Fi Stereo Bass & Crystal-clear Calling: The wireless headphones adopt 10mm speaker which provides stereo sound with deep bass and clear treble. You will hear clear HD stereo sound with punchy bass, reproducing your music vividly. The true wireless earbuds feature noise-canceling calls, effectively reducing background noise, creating a stable and clearer calling environment like you are communicating face to face with others. Latest One-step Pairing Technology: No need to press any button to activate the wireless headphones. This Bluetooth earbuds can be automatically powered on and paired after open the charging case. Meanwhile Bluetooth headphones can also be automatically powered off and charged after putting back into the charging case. Simply one press to answer or reject phone calls, Bluetooth pairing, power on and power off, pretty easy to use. Ergonomic & Lightweight Earhooks: Super lightweight and ergonomic silicone earhooks ensure a secure, comfortable fit for any ear. Long-term strenuous exercise will not fall off or put pressure on the ear. Equipped with 3 pairs of ear caps, which can stay on your ears and get a suitable fitting. These wireless earphones are very suitable for sports,work,driving etc.. IPX7 Waterproof: These wireless sport headphones are rating at IPX7 waterproof, the surface of both in ear earbuds is sealed to prevent sweat or rain from entering, and the internal nano-coating to airborne moisture from damaging the components. Protects the Bluetooth earbuds from slight raindrops or sweat during intense workouts. Widely applied to running, exercises, gym, travel, even on a rainy day.', 'first_large_image': 'https://m.media-amazon.com/images/I/31L+aTKcjjL._AC_.jpg', 'average_rating': 4.9, 'rating_number': 272, 'price': 89.99}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=44, version=6, score=0.34285715, payload={'text': "EYIW 2 Pack Headphone Adapter for iPhone [Apple MFi Certified] in 1 Lightning to 3.5mm Earphone Audio & Charger Splitter Adapter, Compatible with 13/13 Pro/12/11/XR/X/8/7, Support All iOS (EY-A04) 【Connection Method】Compatible with all lightning connector devices. iPhone 13/13 Mini/13 Pro/12 Mini/12/12 Pro/12 Pro Max/11/11 Pro/11 Pro Max/XS/XS Max /XR/X/8/8 Plus/7/7 Plus/iPad, Plug and Play. 【Efficient Transmissio】The headphone adapter is built with an upgraded chip to read data fast and ensure the stability and fidelity of sound transmission, giving you a fantastic music trip and experience when using this aux cord. 【High-Quality Sound】The iPhone adapter uses 100% copper core to provide lossless digital sound quality, supports 48KHz and 24-bit audio output, ensuring sound transmission stability and fidelity. Allows you to enjoy perfect music while charging. 【Connection Method】Just insert your charger or earphones into the jack and then it plays, Plug and Play, lightweight and convenient, you can put it into a backpack or handbag relievedly if you often go out. Recommended gifts to family and friends. 【Enjoy The Service】we are committed to providing satisfactory service to all our customers, and we will treat every customer sincerely and track each customer's orders. Don't hesitate anymore, add it to your cart .", 'first_large_image': 'https://m.media-amazon.com/images/I/41DtrEX4zBL._AC_.jpg', 'average_rating': 3.8, 'rating_number': 208, 'price': None}, vector=None, shard_key=None, order_value=None),
#  ScoredPoint(id=21, version=6, score=0.2, payload={'text': 'RP-TCM125-A in-Ear Buds w/Mic & Remote for Smartphone Mic and Remote Control Ergonomic design conforming to your ear canal S/ M/ L Sized Soft Ear Pieces Cord length 1.1m 10Hz - 24kHz Frequency response', 'first_large_image': 'https://m.media-amazon.com/images/I/414OtjLaqCL._AC_.jpg', 'average_rating': 4.2, 'rating_number': 165, 'price': 13.6}, vector=None, shard_key=None, order_value=None)]

# %%
import instructor
from pydantic import BaseModel
from openai import OpenAI

# %%
class RAGGenerationResponse(BaseModel):
    answer: str

client = instructor.from_openai(OpenAI())

# response -> pydantic response, raw_response -> raw response from openai

prompt = 'You are a helpful assistant. Return an answer to the question: "What is the capital of France?"'

response, raw_response = client.chat.completions.create_with_completion(
    model="gpt-4.1",
    response_model=RAGGenerationResponse,
    messages=[
        {
            "role": "user",
            "content": prompt
        }
    ],
    temperature=0.5,
)

# %%
def kwadraty(n):
    for i in range(n):
        yield i * i

gen = kwadraty(5)

print(next(gen))
print(next(gen))
print(next(gen))
# Out:
# 0
# 1
# 4

# %%
def licz_do_trzech():
    yield 1
    yield 2
    yield 3

for liczba in licz_do_trzech():
    print(liczba)
# Out:
# 1
# 2
# 3
